# %%
# Imports

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#import plotly.express as px
#import plotly.graph_objects as go

# %%
# Import dataset

hotel_data = pd.read_csv('100_hotels.csv')

# %% [markdown]
# # Describe Data

# %% [markdown]
# ### Display the datatypes of our dataset with dtypes

# %%
hotel_data.dtypes
# Out:
# Hotel        object
# Location     object
# Country      object
# Region       object
# Company      object
# Score       float64
# Rank          int64
# Rooms         int64
# Theme        object
# Year          int64
# dtype: object

# %%
hotel_data.columns
# Out:
# Index(['Hotel', 'Location', 'Country', 'Region', 'Company', 'Score', 'Rank',
#        'Rooms', 'Theme', 'Year'],
#       dtype='object')

# %%
hotel_data.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
hotel_data
# Out:
#                               Hotel                      Location  \
# 0                      Mahali Mzuri                    Masai Mara
# 1               Nayara Tented Group  Arenal Volcano National Park
# 2                The Opposite House                       Beijing
# 3                   Capella Bangkok                       Bangkok
# 4                      Capella Ubud                          Bali
# ..                              ...                           ...
# 95                Rosewood Mayakoba              Playa del Carmen
# 96       Canaves Oia Boutique Hotel                     Santorini
# 97                Montage Los Cabos                Cabo San Lucas
# 98           Badrutt's Palace Hotel                    St. Moritz
# 99  Finca Cortesin Hotel Golf & Spa                        M�laga
#
#         Country          Region                      Company  Score  Rank  \
# 0         Kenya          Africa       Virgin Limited Edition  99.73     1
# ...

# %%
hotel_data.describe()
# Out:
#            Score       Rank       Rooms         Year
# count  100.00000  100.00000  100.000000   100.000000
# mean    97.79010   50.13000   95.260000  1986.720000
# std      0.77586   28.87439   95.539047    42.903481
# min     96.63000    1.00000    4.000000  1834.000000
# 25%     97.16500   25.00000   25.000000  1981.000000
# 50%     97.67000   50.50000   66.000000  2006.000000
# 75%     98.40000   75.25000  122.500000  2014.000000
# max     99.73000  100.00000  469.000000  2020.000000

# %%
hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Hotel     100 non-null    object
#  1   Location  100 non-null    object
#  2   Country   100 non-null    object
#  3   Region    100 non-null    object
#  4   Company   100 non-null    object
#  5   Score     100 non-null    float64
#  6   Rank      100 non-null    int64
#  7   Rooms     100 non-null    int64
#  8   Theme     100 non-null    object
#  9   Year      100 non-null    int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 7.9+ KB

# %%
hotel_data.loc[4]
# Out:
# Hotel             Capella Ubud
# Location                  Bali
# Country              Indonesia
# Region          Southeast Asia
# Company     Pontiac Land Group
# Score                    99.34
# Rank                         5
# Rooms                       23
# Theme                   Nature
# Year                      2018
# Name: 4, dtype: object

# %%
hotel_data['Country']
# Out:
# 0           Kenya
# 1      Costa Rica
# 2           China
# 3        Thailand
# 4       Indonesia
#          ...
# 95         Mexico
# 96         Greece
# 97         Mexico
# 98    Switzerland
# 99          Spain
# Name: Country, Length: 100, dtype: object

# %%
hotel_data[hotel_data['Rooms']>=150]
# Out:
#                             Hotel          Location        Country  \
# 9            The Oberoi New Delhi         New Delhi          India
# 18           Shangri-La the Shard            London        England
# 25           The Peninsula Manila            Manila    Philippines
# 28             Halekulani Okinawa           Okinawa          Japan
# 30         Hyatt Regency Amritsar          Amritsar          India
# 36              The Oberoi Mumbai            Mumbai          India
# 42      Mandarin Oriental Bangkok           Bangkok       Thailand
# 51                Viceroy Chicago           Chicago  United States
# 54           Four Seasons Bangkok           Bangkok       Thailand
# 57                     Taj Palace         New Delhi          India
# 72          The Sukhothai Bangkok           Bangkok       Thailand
# 73               The Oberoi Grand           Kolkata          India
# 74            H�tel Plaza Ath�n�e             Paris         France
# ...

# %%
hotel_data['Rooms'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Manipulating Data

# %%
hotel_data['Hotel'].str.lower()
# Out:
# 0                        mahali mzuri
# 1                 nayara tented group
# 2                  the opposite house
# 3                     capella bangkok
# 4                        capella ubud
#                    ...
# 95                  rosewood mayakoba
# 96         canaves oia boutique hotel
# 97                  montage los cabos
# 98             badrutt's palace hotel
# 99    finca cortesin hotel golf & spa
# Name: Hotel, Length: 100, dtype: object
